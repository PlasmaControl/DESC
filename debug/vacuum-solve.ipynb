# %%
import sys
import os

sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("../"))

# %%
# %matplotlib inline

import desc.io
from desc.vmec import VMECIO
# Out:
# DESC version 0.5.1+205.g755cb41.dirty, using JAX backend, jax version=0.2.25, jaxlib version=0.1.76, dtype=float64
# Using device: CPU, with 7.22 GB available memory

# %%
heliotron_vacuum_desc = desc.io.load(
    "../examples/DESC/current/vacuum/HELIOTRON_output.h5"
)[-1]
w7x_vacuum_desc = desc.io.load("../examples/DESC/current/vacuum/W7X_v2_output.h5")[-1]
# Out:
# /home/kaya/Documents/edu/pton/plasma/DESC/current/desc/io/hdf5_io.py:108: RuntimeWarning: Save attribute '_iota' was not loaded.
#   warnings.warn(

# %%
VMECIO.plot_vmec_comparison(
    equil=heliotron_vacuum_desc,
    vmec_data="../examples/VMEC/wout_HELIOTRON_current.nc",
)
# Out:
# (<Figure size 1152x864 with 6 Axes>,
#  array([<AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>],
#        dtype=object))

# %%
VMECIO.plot_vmec_comparison(
    equil=w7x_vacuum_desc,
    vmec_data="../examples/VMEC/wout_W7X_current.nc",
)
# Out:
# (<Figure size 1152x864 with 6 Axes>,
#  array([<AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <AxesSubplot:xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>],
#        dtype=object))
