# %%
### SAME imports as Xu's fixed version

from desc.transform import Transform
from desc.equilibrium import Equilibrium
from desc.basis import ChebyshevZernikeBasis, chebyshev_z
from desc.compute import compute
from desc.grid import LinearGrid, ConcentricGrid, QuadratureGrid, Grid
from desc.compute.utils import get_transforms
from desc.objectives import (
    FixEndCapLambda,
    FixEndCapR,
    FixEndCapZ,
    FixBoundaryR,
    FixBoundaryZ,
    FixPsi,
    FixPressure,
    FixIota,
    ForceBalance,
    ObjectiveFunction,
    CurrentDensity,
)
import numpy as np
from desc.optimize import Optimizer
from desc.profiles import PowerSeriesProfile
from desc.geometry import FourierRZToroidalSurface
from scipy.constants import mu_0


def chebygrid(N_grid):
    return np.concatenate(
        (
            [0],
            (-np.cos((2 * np.arange(N_grid) + 1) * np.pi / (2 * N_grid)) + 1) * np.pi,
            [2 * np.pi],
        )
    )


def grid_gen(L_grid, M_grid, N_grid, node_pattern="jacobi"):
    LMnodes = ConcentricGrid(L=L_grid, M=M_grid, N=0, node_pattern=node_pattern).nodes[
        :, :2
    ]
    Nnodes = chebygrid(N_grid)
    lm = np.tile(LMnodes, (Nnodes.size, 1))
    n = np.tile(Nnodes.reshape(-1, 1), (1, LMnodes.shape[0])).reshape(-1, 1)
    nodes = np.concatenate((lm, n), axis=1)

    # RG: weights and spacing defined here
    # just for the sake of compilation. Must be checked
    weights = np.ones(nodes.shape[0])
    spacing = np.ones_like(nodes)

    spacing[1:, 1] = np.diff(nodes[:, 1])
    spacing[1:, 2] = np.diff(nodes[:, 2])

    return Grid(nodes, spacing=spacing, weights=weights)


def get_lm_mode(basis, coeff, zeta, L, M, func_zeta=chebyshev_z):
    modes = basis.modes
    lm = 0
    for i, (l, m, n) in enumerate(modes):
        if l == L and m == M:
            lm += func_zeta(zeta, n) * coeff[i]
    return lm

# %%
from desc.objectives import (
    SurfaceQuadraticFlux,
    ToroidalFlux,
    ObjectiveFunction,
)
from desc.magnetic_fields import SplineMagneticField
from desc.geometry import FourierRZToroidalSurface
from desc.optimize import Optimizer
from desc.grid import LinearGrid
from desc.plotting import plot_2d, poincare_plot, plot_boundary, plot_surfaces
import numpy as np

# %%
from desc.coils import MixedCoilSet

# %%
field = MixedCoilSet.from_makegrid_coilfile("simple_coils_MR_9.coils")

# %%
# extcur = [4700.0, 1000.0]
# ext_field = SplineMagneticField.from_mgrid(
#    "../../../tests/inputs/mgrid_test.nc", extcur=extcur
# )
# extcur = [1.0]
# field = SplineMagneticField.from_mgrid(
#    "simple_mirror_MR_9.mgrid", extcur=extcur
# )

# %%
grid = grid_gen(2, 10, 20)

# %%
surface0 = FourierRZToroidalSurface(
    R_lmn=[10, 1, -0.5],
    modes_R=[[0, 0], [1, 0], [1, 2]],
    Z_lmn=[0, -1, 0.5],
    modes_Z=[[0, 0], [-1, 0], [-1, 2]],
    NFP=1,
    sym=False,
    mirror=True,
)

# %%
fig, ax = plot_surfaces(surface0, rho=1.0, theta=0)

# %%
# SurfaceQuadraticFlux objective is the one to use when trying to minimize quadratic flux for a surface
qflux = SurfaceQuadraticFlux(
    surface0,
    field,
    # eval_grid=LinearGrid(M=2 * surface0.M, N=2 * surface0.M, NFP=surface0.NFP),
    eval_grid=grid,
    field_fixed=True,  # field is not being optimized
    bs_chunk_size=10,
)

# %%
# Must include a ToroidalFlux or a Volume target to ensure we don't get a trivial solution of the surface collapsing to a point
target_psi = 6
tflux = ToroidalFlux(
    surface0,
    field,
    target=target_psi,  # the same toroidal flux as used in the free bdry eq
    eq_fixed=False,  # we will allow the thing passed in (QFM surface in this case) to vary
    field_fixed=True,  # field is not being optimized, so we fix it
)
obj = ObjectiveFunction(qflux)

opt = Optimizer("lsq-auglag")

(qfm_surf,), _ = opt.optimize(
    surface0,
    objective=obj,
    constraints=(tflux,),
    ftol=1e-5,
    maxiter=100,
    verbose=3,
    copy=True,
)
# Out:
# Building objective: Surface Quadratic Flux
# Precomputing transforms
# Timer: Precomputing transforms = 593 ms
# Timer: Objective build = 608 ms
# Building objective: toroidal-flux
# Precomputing transforms
# Timer: Precomputing transforms = 225 ms
# Timer: Objective build = 944 ms
# Number of parameters: 18
# Number of objectives: 660
# Number of equality constraints: 1
# Number of inequality constraints: 0
# Timer: Initializing the optimization = 1.63 sec
#
# Starting optimization
# Using method: lsq-auglag
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality    Constr viol.   Penalty param  max(|mltplr|)
#        0              1          1.955e+03                                    4.267e+01      1.940e+00      1.000e+01      0.000e+00
#        1              2          1.907e+03      4.850e+01      1.271e-02      4.154e+01      2.029e+00      1.000e+01      0.000e+00
#        2              3          1.723e+03      1.835e+02      5.066e-02      3.735e+01      2.345e+00      1.000e+01      0.000e+00
#        3              4          1.130e+03      5.932e+02      1.994e-01      2.453e+01      3.136e+00      1.000e+01      0.000e+00
#        4              5          6.032e+01      1.070e+03      7.429e-01      5.559e+00      2.491e+00      1.000e+01      0.000e+00
#        5              6          2.642e+01      3.389e+01      4.875e-01      6.448e+00      3.282e+00      1.000e+01      0.000e+00
#        6              7          3.765e+01     -1.123e+01      1.034e-01      1.337e+00      1.934e+00      1.000e+01      0.000e+00
#        7              9          3.981e+01     -2.157e+00      1.025e-01      6.485e-01      1.557e+00      1.000e+01      0.000e+00
#        8             11          3.802e+01      1.782e+00      1.045e-01      8.697e-01      1.451e+00      1.000e+01      0.000e+00
#        9             13          3.709e+01      9.300e-01      5.090e-02      9.692e-01      1.421e+00      1.000e+01      0.000e+00
#       10             14          3.767e+01     -5.746e-01      8.897e-02      2.142e-01      1.286e+00      1.000e+01      0.000e+00
#       11             15          3.817e+01     -5.044e-01      6.534e-02      1.187e-01      1.228e+00      1.000e+01      0.000e+00
#       12             17          3.773e+01      4.410e-01      3.579e-02      7.688e-02      1.239e+00      1.000e+01      0.000e+00
#       13             19          3.784e+01     -1.074e-01      3.036e-02      5.580e-02      1.220e+00      1.000e+01      0.000e+00
#       14             20          3.792e+01     -7.931e-02      1.245e-01      1.479e-01      1.204e+00      1.000e+01      0.000e+00
#       15             22          3.743e+01      4.924e-01      1.158e-01      1.678e-01      1.189e+00      1.000e+01      0.000e+00
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 2.988e+01
#          Constraint violation: 5.583e-04
#          Total delta_x: 1.863e+00
#          Iterations: 100
#          Function evaluations: 109
#          Jacobian evaluations: 103
# Timer: Solution time = 20.9 sec
# Timer: Avg time per step = 207 ms
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      1.955e+03  -->   2.988e+01,
# Maximum absolute QFM surface normal field error:             2.275e+00  -->   7.314e-01 (T m^2)
# Minimum absolute QFM surface normal field error:             1.469e-05  -->   4.295e-06 (T m^2)
# Average absolute QFM surface normal field error:             4.813e-01  -->   6.301e-02 (T m^2)
# Maximum absolute QFM surface normal field error:             2.275e-01  -->   7.314e-02 (normalized)
# Minimum absolute QFM surface normal field error:             1.469e-06  -->   4.295e-07 (normalized)
# Average absolute QFM surface normal field error:             4.813e-02  -->   6.301e-03 (normalized)
# Maximum Toroidal Flux:                                       4.060e+00  -->   5.999e+00 (Wb)
# Minimum Toroidal Flux:                                       4.060e+00  -->   5.999e+00 (Wb)
# Average Toroidal Flux:                                       4.060e+00  -->   5.999e+00 (Wb)
# Maximum Toroidal Flux:                                       4.060e+00  -->   5.999e+00 (normalized)
# Minimum Toroidal Flux:                                       4.060e+00  -->   5.999e+00 (normalized)
# Average Toroidal Flux:                                       4.060e+00  -->   5.999e+00 (normalized)
# ==============================================================================================================

# %%
# grid = LinearGrid(M=2 * surface0.M, N=2 * surface0.M, NFP=surface0.NFP)

# %%
data = qfm_surf.compute(["X", "Y", "Z"], grid=grid)

# %%
surf_data = surface0.compute(["X", "Y", "Z"], grid=grid)

# %%
coil_data = field.compute(["X", "Y", "Z"])

# %%
import matplotlib.pyplot as plt

# %%
for coils in coil_data:
    x = coils["X"]
    y = coils["Y"]
    z = coils["Z"]
    plt.plot(z, x)

# %%
x = surf_data["X"]
y = surf_data["Y"]
z = surf_data["Z"]
plt.plot(z, x, ".")

# %%
x = data["X"]
y = data["Y"]
z = data["Z"]
plt.plot(z, x, ".")

# %%
from mayavi import mlab

# %%
fig = mlab.figure(bgcolor=(1, 1, 1), fgcolor=(0.0, 0.0, 0.0))

for coils in coil_data:
    x = coils["X"]
    y = coils["Y"]
    z = coils["Z"]
    points = mlab.points3d(
        x, y, z, scale_factor=0.1, scale_mode="none", color=(0, 0, 1)
    )


x = surf_data["X"]
y = surf_data["Y"]
z = surf_data["Z"]
points = mlab.points3d(x, y, z, scale_factor=0.1, color=(1, 0, 0))


x = data["X"]
y = data["Y"]
z = data["Z"]
points = mlab.points3d(x, y, z, scale_factor=0.1, scale_mode="none")

# mlab.colorbar()


mlab.show()

# %%
### Now make a vaccum eq
surface = qfm_surf.copy()

# %%
# import first or else jupyter crashes

from desc.plotting import plot_section
from desc.plotting import (
    plot_grid,
    plot_boozer_modes,
    plot_boozer_surface,
    plot_qs_error,
    plot_boundaries,
    plot_boundary,
)
import desc
import matplotlib.pyplot as plt
from desc.basis import ChebyshevFourierSeries


from desc.transform import Transform
from desc.equilibrium import Equilibrium
from desc.basis import ChebyshevZernikeBasis, chebyshev_z
from desc.compute import compute
from desc.grid import LinearGrid, ConcentricGrid, QuadratureGrid, Grid
from desc.compute.utils import get_transforms
from desc.objectives import (
    FixEndCapLambda,
    FixEndCapR,
    FixEndCapZ,
    FixBoundaryR,
    FixBoundaryZ,
    FixPsi,
    FixPressure,
    FixIota,
    ForceBalance,
    ObjectiveFunction,
    CurrentDensity,
    MatchEndCapR,
    MatchEndCapZ,
    MatchEndCapLambda,
    ForceBalanceAnisotropic,
    MagneticWell,
    FixAnisotropy,
)
import numpy as np
from desc.optimize import Optimizer
from desc.profiles import PowerSeriesProfile
from desc.geometry import FourierRZToroidalSurface
from scipy.constants import mu_0
from mayavi import mlab


def chebygrid(N_grid):
    return np.concatenate(
        (
            [0],
            (-np.cos((2 * np.arange(N_grid) + 1) * np.pi / (2 * N_grid)) + 1) * np.pi,
            [2 * np.pi],
        )
    )


def grid_gen(L_grid, M_grid, N_grid, node_pattern="jacobi"):
    LMnodes = ConcentricGrid(L=L_grid, M=M_grid, N=0, node_pattern=node_pattern).nodes[
        :, :2
    ]
    Nnodes = chebygrid(N_grid)
    lm = np.tile(LMnodes, (Nnodes.size, 1))
    n = np.tile(Nnodes.reshape(-1, 1), (1, LMnodes.shape[0])).reshape(-1, 1)
    nodes = np.concatenate((lm, n), axis=1)

    # RG: weights and spacing defined here
    # just for the sake of compilation. Must be checked
    weights = np.ones(nodes.shape[0])
    spacing = np.ones_like(nodes)

    spacing[1:, 1] = np.diff(nodes[:, 1])
    spacing[1:, 2] = np.diff(nodes[:, 2])

    return Grid(nodes, spacing=spacing, weights=weights)


def get_lm_mode(basis, coeff, zeta, L, M, func_zeta=chebyshev_z):
    modes = basis.modes
    lm = 0
    for i, (l, m, n) in enumerate(modes):
        if l == L and m == M:
            lm += func_zeta(zeta, n) * coeff[i]
    return lm


plt.rcParams.update(
    {
        "font.size": 16,  # Default text size
        "axes.titlesize": 18,  # Title font
        "axes.labelsize": 16,  # x/y label font
        "xtick.labelsize": 14,  # Tick font
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
    }
)


p = PowerSeriesProfile(params=[0.001 / mu_0, -0.001 / mu_0], modes=[0, 2])
iota = PowerSeriesProfile(params=[0.0, 0])

# %%
p.set_params(0, a=0e6)  # = array([-1000])
p.set_params(2, a=-0e6)  # = array([-1000])

# %%
surface._length
# Out:
# Array(62.83185307, dtype=float64)

# %%
eq = Equilibrium(
    surface=surface,
    L=5,
    M=2,
    N=12,
    mirror=True,
    pressure=p,
    iota=iota,
    sym=False,
)

# %%
eq_start = eq.copy()

# %%
# ---- Grid for axis (rho = 0, theta = 0, zeta from 0 to 2pi) ----
zeta_axis = np.linspace(0, 2 * np.pi, 64)
rho_axis = np.zeros_like(zeta_axis)
theta_axis = np.zeros_like(zeta_axis)
grid_axis = Grid(np.stack([rho_axis, theta_axis, zeta_axis], axis=1))

# Compute on axis
data_axis = eq.compute(["|B|", "p", "beta_a", "Y"], grid=grid_axis)
B_axis = data_axis["|B|"]
p_perp_axis = data_axis["p"]

plt.figure()
plt.plot(zeta_axis, B_axis)
plt.title("MR = {}".format(np.max(B_axis) / np.min(B_axis)))
# Out:
# Text(0.5, 1.0, 'MR = 6.381878212116186')

# %%
constraints = (
    # FixEndCapLambda(0, eq=eq),
    # FixEndCapR(0, eq=eq),
    # FixEndCapZ(0, eq=eq),
    # FixEndCapLambda(2*np.pi, eq=eq),
    # FixEndCapR(2*np.pi, eq=eq),
    # FixEndCapZ(2*np.pi, eq=eq),
    MatchEndCapR(eq=eq),
    # MatchEndCapZ(eq=eq),
    MatchEndCapLambda(eq=eq),
    # EndCapMatchLambda_Rot(eq=eq),
    # EndCapMatchR_Rot(eq=eq),
    # EndCapMatchZ_Rot(eq=eq),
    # FixBoundaryR(eq=eq),
    FixBoundaryZ(eq=eq),
    FixPressure(eq=eq),
    FixIota(eq=eq),
    FixPsi(eq=eq),
    # FixAnisotropy(eq=eq),
)
optimizer = Optimizer("lsq-exact")
grid = grid_gen(10, 20, 20)


# objectives = CurrentDensity(eq=eq, grid=grid)
# objectives = ForceBalance(eq=eq, grid=grid)
# objectives = [ForceBalance(eq=eq, grid=grid), 100.0 * symmetry_obj]
# obj = ObjectiveFunction(objectives=objectives)
# force_obj = ForceBalanceAnisotropic(eq=eq, grid=grid)
# obj = ObjectiveFunction(objectives=[force_obj])

aFB = ForceBalance(eq=eq, grid=grid)

stab = MagneticWell(eq=eq)
obj = ObjectiveFunction(objectives=[aFB])

eq.solve(
    objective=obj,
    constraints=constraints,
    optimizer=optimizer,
    ftol=1e-8,
    xtol=1e-16,
    gtol=1e-16,
    maxiter=20,
    verbose=3,
)
# Out:
# Building objective: force
# Precomputing transforms
# Timer: Precomputing transforms = 199 ms
# Timer: Objective build = 228 ms
# Building objective: MatchR at Endcaps
# Building objective: MatchL at Endcaps
# Building objective: lcfs Z
# Building objective: fixed pressure
# Building objective: fixed iota
# Building objective: fixed Psi
# Building objective: self_consistency R
# Building objective: self_consistency Z
# Building objective: lambda gauge
# Building objective: axis R self consistency
# Building objective: axis Z self consistency
# Timer: Objective build = 71.7 ms
# Timer: LinearConstraintProjection build = 60.7 ms
# Number of parameters: 380
# Number of objectives: 6072
# Timer: Initializing the optimization = 367 ms
#
# Starting optimization
# Using method: lsq-exact
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1          3.506e-01                                    1.530e-01
#        1              5          2.921e-01      5.851e-02      1.414e-01      1.003e-01
#        2              7          2.638e-01      2.832e-02      6.203e-02      9.561e-02
#        3              8          2.610e-01      2.775e-03      1.080e-01      2.116e-01
#        4              9          2.145e-01      4.657e-02      4.138e-02      8.361e-02
#        5             10          2.032e-01      1.123e-02      5.695e-02      1.154e-01
#        6             11          1.811e-01      2.217e-02      5.953e-02      8.977e-02
#        7             12          1.610e-01      2.009e-02      5.292e-02      5.154e-02
#        8             13          1.441e-01      1.685e-02      8.401e-02      7.062e-02
#        9             14          1.241e-01      1.998e-02      1.402e-01      1.028e-01
#       10             15          1.008e-01      2.333e-02      1.319e-01      8.176e-02
#       11             17          8.570e-02      1.511e-02      6.726e-02      3.212e-02
#       12             18          7.540e-02      1.030e-02      1.244e-01      7.638e-02
#       13             19          6.136e-02      1.404e-02      1.162e-01      6.030e-02
#       14             21          5.228e-02      9.081e-03      5.814e-02      2.699e-02
#       15             22          4.728e-02      4.998e-03      1.083e-01      6.696e-02
#       16             23          4.240e-02      4.885e-03      1.049e-01      9.361e-02
#       17             24          3.988e-02      2.517e-03      1.076e-01      1.238e-01
#       18             25          2.629e-02      1.359e-02      3.222e-02      2.656e-02
#       19             26          2.447e-02      1.822e-03      5.677e-02      3.880e-02
#       20             27          2.157e-02      2.903e-03      5.095e-02      1.560e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 2.157e-02
#          Total delta_x: 1.438e+00
#          Iterations: 20
#          Function evaluations: 27
#          Jacobian evaluations: 21
# Timer: Solution time = 8.21 sec
# Timer: Avg time per step = 391 ms
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      3.506e-01  -->   2.157e-02,
# Maximum absolute Force error:                                5.341e+03  -->   1.215e+03 (N)
# Minimum absolute Force error:                                8.431e-02  -->   4.019e-02 (N)
# Average absolute Force error:                                5.953e+02  -->   1.656e+02 (N)
# Maximum absolute Force error:                                1.175e-03  -->   2.673e-04 (normalized)
# Minimum absolute Force error:                                1.855e-08  -->   8.842e-09 (normalized)
# Average absolute Force error:                                1.310e-04  -->   3.644e-05 (normalized)
# Fixed-R sum modes error                                      2.215e-14  -->   2.186e-14 (m)
# Fixed-L sum modes error:                                     6.166e-15  -->   6.146e-15 (m)
# Z boundary error:                                            0.000e+00  -->   1.570e-16 (m)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed iota profile error:                                    0.000e+00  -->   0.000e+00 (dimensionless)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# ==============================================================================================================
# (Equilibrium at 0x321b99d10 (L=5, M=2, N=12, NFP=1, sym=False, spectral_indexing=ansi),
#            message: Maximum number of iterations has been exceeded.
#            success: False
#                fun: [-9.641e-04  3.881e-06 ... -7.360e-03 -4.953e-03]
#                  x: [-8.908e-01  2.790e+00 ...  5.372e-02  7.637e-02]
#                nit: 20
#               cost: 0.021566193673738434
#                  v: [ 1.000e+00  1.000e+00 ...  1.000e+00  1.000e+00]
#         optimality: 0.01560047528363624
#               nfev: 27
#               njev: 21
#               allx: [Array([ 9.870e+00, -1.746e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.871e+00, -1.760e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.873e+00, -1.767e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.875e+00, -1.778e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.876e+00, -1.780e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.877e+00, -1.783e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.878e+00, -1.787e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.879e+00, -1.790e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.880e+00, -1.796e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.883e+00, -1.809e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.886e+00, -1.821e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.887e+00, -1.826e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.888e+00, -1.835e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.888e+00, -1.842e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.889e+00, -1.843e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.888e+00, -1.844e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.885e+00, -1.844e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.883e+00, -1.842e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.883e+00, -1.840e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.882e+00, -1.839e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), Array([ 9.880e+00, -1.840e+00, ...,  0.000e+00,
#                             0.000e+00], dtype=float64)]
#              alltr: [Array( 3.091e+04, dtype=float64), np.float64(7728.5636320551475), np.float64(1932.1409080137862), np.float64(483.03522700344655), np.float64(966.0704540068931), np.float64(241.5176135017233), np.float64(483.03522700344655), np.float64(120.75880675086162), np.float64(241.51761350172328), np.float64(241.51761350172328), np.float64(241.51761350172328), np.float64(483.0352270034466), np.float64(966.0704540068932), np.float64(966.0704540068932), np.float64(1932.1409080137864), np.float64(483.03522700344655), np.float64(966.0704540068932), np.float64(966.0704540068932), np.float64(1932.1409080137864), np.float64(483.0352270034466), np.float64(966.0704540068934), np.float64(966.0704540068934), np.float64(966.0704540068934), np.float64(241.5176135017234), np.float64(483.0352270034468), np.float64(483.0352270034468), np.float64(966.0704540068936)]
#            history: [[{'R_lmn': Array([ 9.870e+00, -1.746e+00, ...,  6.554e-05,
#                             5.098e-05], dtype=float64), 'Z_lmn': Array([ 4.624e-02, -8.721e-01, ...,  1.237e-05,
#                            -7.291e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -1.782e-01, ..., -1.421e-05,
#                             2.575e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.826e+00,  6.186e-03, ..., -8.210e-05,
#                            -1.593e-04], dtype=float64), 'Za_n': Array([ 4.541e-02, -2.010e-03, ...,  3.078e-06,
#                             7.582e-05], dtype=float64), 'Rb_lmn': Array([ 9.724e-02, -1.781e+00, ...,  4.158e-06,
#                            -1.173e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.871e+00, -1.760e+00, ...,  6.857e-05,
#                             6.055e-05], dtype=float64), 'Z_lmn': Array([ 4.871e-02, -8.771e-01, ..., -2.002e-05,
#                            -7.320e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -2.147e-01, ..., -2.467e-05,
#                             1.926e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.825e+00,  5.634e-03, ..., -7.304e-05,
#                            -1.459e-04], dtype=float64), 'Za_n': Array([ 5.121e-02, -3.930e-03, ...,  1.288e-05,
#                             9.685e-05], dtype=float64), 'Rb_lmn': Array([ 9.484e-02, -1.778e+00, ...,  1.987e-05,
#                            -1.244e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.873e+00, -1.767e+00, ...,  7.236e-05,
#                             6.538e-05], dtype=float64), 'Z_lmn': Array([ 5.212e-02, -8.791e-01, ..., -5.223e-05,
#                            -5.451e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -2.358e-01, ..., -3.268e-05,
#                             2.009e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.824e+00,  5.215e-03, ..., -6.913e-05,
#                            -1.407e-04], dtype=float64), 'Za_n': Array([ 5.885e-02, -4.661e-03, ...,  1.295e-05,
#                             1.435e-04], dtype=float64), 'Rb_lmn': Array([ 9.209e-02, -1.776e+00, ...,  2.571e-05,
#                            -1.517e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.875e+00, -1.778e+00, ...,  8.007e-05,
#                             4.836e-05], dtype=float64), 'Z_lmn': Array([ 5.787e-02, -8.820e-01, ..., -9.846e-05,
#                            -2.660e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -2.649e-01, ..., -3.674e-05,
#                             1.736e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.823e+00,  4.312e-03, ..., -7.124e-05,
#                            -1.305e-04], dtype=float64), 'Za_n': Array([ 7.289e-02, -5.409e-03, ...,  6.199e-06,
#                             1.786e-04], dtype=float64), 'Rb_lmn': Array([ 8.508e-02, -1.771e+00, ...,  1.750e-05,
#                            -1.734e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.876e+00, -1.780e+00, ...,  7.983e-05,
#                             3.556e-05], dtype=float64), 'Z_lmn': Array([ 5.918e-02, -8.821e-01, ..., -1.313e-04,
#                             5.952e-06], dtype=float64), 'L_lmn': Array([ 0.000e+00, -2.917e-01, ..., -3.385e-05,
#                             2.417e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.823e+00,  4.014e-03, ..., -7.169e-05,
#                            -1.310e-04], dtype=float64), 'Za_n': Array([ 7.701e-02, -5.399e-03, ...,  3.644e-06,
#                             2.018e-04], dtype=float64), 'Rb_lmn': Array([ 8.294e-02, -1.767e+00, ..., -1.503e-07,
#                            -2.069e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.877e+00, -1.783e+00, ...,  7.734e-05,
#                             8.128e-06], dtype=float64), 'Z_lmn': Array([ 6.169e-02, -8.827e-01, ..., -1.643e-04,
#                             2.786e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -3.189e-01, ..., -3.551e-05,
#                             2.618e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.823e+00,  3.537e-03, ..., -7.569e-05,
#                            -1.108e-04], dtype=float64), 'Za_n': Array([ 8.489e-02, -5.376e-03, ..., -7.960e-06,
#                             2.149e-04], dtype=float64), 'Rb_lmn': Array([ 7.860e-02, -1.762e+00, ..., -1.989e-05,
#                            -2.202e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.878e+00, -1.787e+00, ...,  7.309e-05,
#                            -2.679e-05], dtype=float64), 'Z_lmn': Array([ 6.084e-02, -8.827e-01, ..., -1.815e-04,
#                             3.771e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -3.552e-01, ..., -3.931e-05,
#                             2.647e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.822e+00,  3.189e-03, ..., -7.614e-05,
#                            -9.126e-05], dtype=float64), 'Za_n': Array([ 8.696e-02, -5.360e-03, ..., -1.956e-05,
#                             2.070e-04], dtype=float64), 'Rb_lmn': Array([ 7.433e-02, -1.759e+00, ..., -4.148e-05,
#                            -2.206e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.879e+00, -1.790e+00, ...,  7.281e-05,
#                            -5.355e-05], dtype=float64), 'Z_lmn': Array([ 5.854e-02, -8.822e-01, ..., -1.897e-04,
#                             3.841e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -3.863e-01, ..., -4.740e-05,
#                             2.276e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.822e+00,  2.862e-03, ..., -7.164e-05,
#                            -7.289e-05], dtype=float64), 'Za_n': Array([ 8.553e-02, -5.351e-03, ..., -3.155e-05,
#                             1.976e-04], dtype=float64), 'Rb_lmn': Array([ 7.028e-02, -1.756e+00, ..., -4.505e-05,
#                            -2.142e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.880e+00, -1.796e+00, ...,  8.063e-05,
#                            -7.793e-05], dtype=float64), 'Z_lmn': Array([ 5.325e-02, -8.795e-01, ..., -1.974e-04,
#                             3.815e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -4.223e-01, ..., -5.596e-05,
#                             1.723e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.822e+00,  2.111e-03, ..., -6.501e-05,
#                            -7.717e-05], dtype=float64), 'Za_n': Array([ 7.866e-02, -5.065e-03, ..., -4.237e-05,
#                             1.871e-04], dtype=float64), 'Rb_lmn': Array([ 6.162e-02, -1.749e+00, ..., -2.678e-05,
#                            -1.894e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.883e+00, -1.809e+00, ...,  8.772e-05,
#                            -9.898e-05], dtype=float64), 'Z_lmn': Array([ 4.462e-02, -8.717e-01, ..., -1.962e-04,
#                             3.625e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -4.541e-01, ..., -5.496e-05,
#                             1.232e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.822e+00,  8.795e-04, ..., -4.586e-05,
#                            -9.945e-05], dtype=float64), 'Za_n': Array([ 6.879e-02, -4.242e-03, ..., -4.594e-05,
#                             1.489e-04], dtype=float64), 'Rb_lmn': Array([ 4.493e-02, -1.736e+00, ...,  7.121e-06,
#                            -1.277e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.886e+00, -1.821e+00, ...,  7.800e-05,
#                            -9.738e-05], dtype=float64), 'Z_lmn': Array([ 3.577e-02, -8.631e-01, ..., -1.831e-04,
#                             3.446e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -4.747e-01, ..., -4.467e-05,
#                             8.388e-06], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.823e+00, -1.799e-04, ..., -2.400e-05,
#                            -1.055e-04], dtype=float64), 'Za_n': Array([ 5.964e-02, -3.378e-03, ..., -3.206e-05,
#                             1.296e-04], dtype=float64), 'Rb_lmn': Array([ 2.814e-02, -1.719e+00, ...,  5.209e-05,
#                            -5.545e-05], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.887e+00, -1.826e+00, ...,  7.583e-05,
#                            -8.927e-05], dtype=float64), 'Z_lmn': Array([ 3.098e-02, -8.585e-01, ..., -1.784e-04,
#                             3.765e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -4.859e-01, ..., -3.746e-05,
#                             7.600e-06], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.823e+00, -5.954e-04, ..., -1.379e-05,
#                            -1.028e-04], dtype=float64), 'Za_n': Array([ 5.491e-02, -2.932e-03, ..., -1.753e-05,
#                             1.318e-04], dtype=float64), 'Rb_lmn': Array([ 1.866e-02, -1.706e+00, ...,  8.913e-05,
#                            -7.399e-06], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.888e+00, -1.835e+00, ...,  6.779e-05,
#                            -6.674e-05], dtype=float64), 'Z_lmn': Array([ 2.118e-02, -8.493e-01, ..., -1.641e-04,
#                             3.818e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -5.024e-01, ..., -2.932e-05,
#                             7.742e-06], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.825e+00, -1.085e-03, ..., -3.029e-06,
#                            -9.684e-05], dtype=float64), 'Za_n': Array([ 4.310e-02, -2.369e-03, ...,  4.824e-06,
#                             1.498e-04], dtype=float64), 'Rb_lmn': Array([ 1.883e-03, -1.685e+00, ...,  1.141e-04,
#                             5.070e-05], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.888e+00, -1.842e+00, ...,  6.832e-05,
#                            -4.377e-05], dtype=float64), 'Z_lmn': Array([ 1.368e-02, -8.407e-01, ..., -1.500e-04,
#                             4.603e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -5.146e-01, ..., -2.468e-05,
#                             1.087e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.827e+00, -1.344e-03, ...,  6.035e-06,
#                            -8.281e-05], dtype=float64), 'Za_n': Array([ 3.464e-02, -2.021e-03, ...,  2.620e-05,
#                             1.786e-04], dtype=float64), 'Rb_lmn': Array([-1.419e-02, -1.662e+00, ...,  1.319e-04,
#                             9.438e-05], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.889e+00, -1.843e+00, ...,  7.146e-05,
#                            -3.760e-05], dtype=float64), 'Z_lmn': Array([ 9.176e-03, -8.356e-01, ..., -1.429e-04,
#                             5.447e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -5.285e-01, ..., -2.236e-05,
#                             1.266e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.828e+00, -1.434e-03, ...,  9.103e-06,
#                            -7.535e-05], dtype=float64), 'Za_n': Array([ 2.771e-02, -1.768e-03, ...,  4.426e-05,
#                             2.037e-04], dtype=float64), 'Rb_lmn': Array([-2.217e-02, -1.644e+00, ...,  1.380e-04,
#                             1.243e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.888e+00, -1.844e+00, ...,  6.986e-05,
#                            -3.080e-05], dtype=float64), 'Z_lmn': Array([ 1.547e-03, -8.266e-01, ..., -1.293e-04,
#                             6.570e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -5.505e-01, ..., -2.009e-05,
#                             1.436e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.830e+00, -1.530e-03, ...,  1.615e-05,
#                            -6.067e-05], dtype=float64), 'Za_n': Array([ 1.558e-02, -1.473e-03, ...,  6.022e-05,
#                             2.397e-04], dtype=float64), 'Rb_lmn': Array([-3.880e-02, -1.615e+00, ...,  1.300e-04,
#                             1.546e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.885e+00, -1.844e+00, ...,  6.857e-05,
#                            -3.684e-05], dtype=float64), 'Z_lmn': Array([-4.972e-03, -8.174e-01, ..., -1.152e-04,
#                             7.760e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -5.786e-01, ..., -1.817e-05,
#                             1.404e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.833e+00, -1.541e-03, ...,  2.056e-05,
#                            -4.751e-05], dtype=float64), 'Za_n': Array([ 3.903e-03, -1.193e-03, ...,  7.190e-05,
#                             2.695e-04], dtype=float64), 'Rb_lmn': Array([-5.531e-02, -1.583e+00, ...,  1.070e-04,
#                             1.728e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.883e+00, -1.842e+00, ...,  6.501e-05,
#                            -4.950e-05], dtype=float64), 'Z_lmn': Array([-1.157e-02, -8.080e-01, ..., -1.008e-04,
#                             8.780e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -6.144e-01, ..., -1.633e-05,
#                             1.304e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.836e+00, -1.611e-03, ...,  2.505e-05,
#                            -3.927e-05], dtype=float64), 'Za_n': Array([-7.947e-03, -9.622e-04, ...,  7.657e-05,
#                             2.886e-04], dtype=float64), 'Rb_lmn': Array([-7.224e-02, -1.548e+00, ...,  7.433e-05,
#                             1.760e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.883e+00, -1.840e+00, ...,  6.686e-05,
#                            -5.551e-05], dtype=float64), 'Z_lmn': Array([-1.314e-02, -8.046e-01, ..., -9.423e-05,
#                             9.335e-05], dtype=float64), 'L_lmn': Array([ 0.000e+00, -6.293e-01, ..., -1.468e-05,
#                             1.116e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.837e+00, -1.708e-03, ...,  2.636e-05,
#                            -3.976e-05], dtype=float64), 'Za_n': Array([-1.045e-02, -9.267e-04, ...,  7.884e-05,
#                             2.894e-04], dtype=float64), 'Rb_lmn': Array([-7.634e-02, -1.533e+00, ...,  5.797e-05,
#                             1.724e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.882e+00, -1.839e+00, ...,  6.588e-05,
#                            -6.032e-05], dtype=float64), 'Z_lmn': Array([-1.694e-02, -7.995e-01, ..., -8.711e-05,
#                             1.000e-04], dtype=float64), 'L_lmn': Array([ 0.000e+00, -6.525e-01, ..., -1.484e-05,
#                             1.210e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.839e+00, -1.814e-03, ...,  2.856e-05,
#                            -3.744e-05], dtype=float64), 'Za_n': Array([-1.663e-02, -9.354e-04, ...,  7.764e-05,
#                             2.946e-04], dtype=float64), 'Rb_lmn': Array([-8.406e-02, -1.514e+00, ...,  4.052e-05,
#                             1.707e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}], [{'R_lmn': Array([ 9.880e+00, -1.840e+00, ...,  6.601e-05,
#                            -6.147e-05], dtype=float64), 'Z_lmn': Array([-1.945e-02, -7.955e-01, ..., -8.257e-05,
#                             1.046e-04], dtype=float64), 'L_lmn': Array([ 0.000e+00, -6.684e-01, ..., -1.595e-05,
#                             1.310e-05], dtype=float64), 'p_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'i_l': Array([ 0.000e+00,  0.000e+00,  0.000e+00], dtype=float64), 'c_l': Array([], shape=(0,), dtype=float64), 'Psi': Array([ 1.000e+00], dtype=float64), 'Te_l': Array([], shape=(0,), dtype=float64), 'ne_l': Array([], shape=(0,), dtype=float64), 'Ti_l': Array([], shape=(0,), dtype=float64), 'Zeff_l': Array([], shape=(0,), dtype=float64), 'a_lmn': Array([], shape=(0,), dtype=float64), 'Ra_n': Array([ 9.841e+00, -1.964e-03, ...,  2.910e-05,
#                            -3.504e-05], dtype=float64), 'Za_n': Array([-2.038e-02, -1.012e-03, ...,  7.471e-05,
#                             2.929e-04], dtype=float64), 'Rb_lmn': Array([-9.079e-02, -1.499e+00, ...,  2.368e-05,
#                             1.631e-04], dtype=float64), 'Zb_lmn': Array([ 0.000e+00, -8.457e-01, ...,  0.000e+00,
#                             0.000e+00], dtype=float64), 'I': Array([], shape=(0,), dtype=float64), 'G': Array([], shape=(0,), dtype=float64), 'Phi_mn': Array([], shape=(0,), dtype=float64)}]]
#   Objective values:         Total (sum of squares):  f: 0.02156619367373844
#                                                     f0: 0.3506292247113202
#                                      Force error: : [{'f_max': Array( 1.215e+03,      dtype=float64), 'f0_max': Array( 5.341e+03,      dtype=float64), 'f_min': Array( 4.019e-02,      dtype=float64), 'f0_min': Array( 8.431e-02,      dtype=float64), 'f_mean': Array( 1.656e+02,      dtype=float64), 'f0_mean': Array( 5.953e+02,      dtype=float64), 'f_max_norm': Array( 2.673e-04,      dtype=float64), 'f0_max_norm': Array( 1.175e-03,      dtype=float64), 'f_min_norm': Array( 8.842e-09,      dtype=float64), 'f0_min_norm': Array( 1.855e-08,      dtype=float64), 'f_mean_norm': Array( 3.644e-05,      dtype=float64), 'f0_mean_norm': Array( 1.310e-04,      dtype=float64)}]
#                            Fixed-R sum modes error: [{'f': Array( 2.186e-14,      dtype=float64), 'f0': Array( 2.215e-14,      dtype=float64)}]
#                           Fixed-L sum modes error:: [{'f': Array( 6.146e-15,      dtype=float64), 'f0': Array( 6.166e-15,      dtype=float64)}]
#                                 Z boundary error: : [{'f': Array( 1.570e-16,      dtype=float64), 'f0': Array( 0.000e+00,      dtype=float64)}]
#                     Fixed pressure profile error: : [{'f': Array( 0.000e+00,      dtype=float64), 'f0': Array( 0.000e+00,      dtype=float64)}]
#                         Fixed iota profile error: : [{'f': Array( 0.000e+00,      dtype=float64), 'f0': Array( 0.000e+00,      dtype=float64)}]
#                                  Fixed Psi error: : [{'f': Array( 0.000e+00,      dtype=float64), 'f0': Array( 0.000e+00,      dtype=float64)}])

# %%
f = (
    eq.compute("<|F|>_vol")["<|F|>_vol"]
    / eq.compute("<|grad(|B|^2)|/2mu0>_vol")["<|grad(|B|^2)|/2mu0>_vol"]
)

print(f"Force error after eq.solve(): {f:.4e}")
# Out:
# Force error after eq.solve(): 1.5337e-02

# %%
from desc.plotting import *

# %%
plot_section(eq, "|F|", norm_F=True, log=True)
# Out:
# (<Figure size 1080.81x720.54 with 12 Axes>,
#  array([<Axes: title={'center': '$|\\mathbf{J} \\times \\mathbf{B} - \\nabla p|$ / $\\langle |\\nabla |B|^{2}/(2\\mu_0)| \\rangle_{vol}$, $\\phi \\cdot N_{FP}/2\\pi = 0.000$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <Axes: title={'center': '$|\\mathbf{J} \\times \\mathbf{B} - \\nabla p|$ / $\\langle |\\nabla |B|^{2}/(2\\mu_0)| \\rangle_{vol}$, $\\phi \\cdot N_{FP}/2\\pi = 0.167$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <Axes: title={'center': '$|\\mathbf{J} \\times \\mathbf{B} - \\nabla p|$ / $\\langle |\\nabla |B|^{2}/(2\\mu_0)| \\rangle_{vol}$, $\\phi \\cdot N_{FP}/2\\pi = 0.333$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <Axes: title={'center': '$|\\mathbf{J} \\times \\mathbf{B} - \\nabla p|$ / $\\langle |\\nabla |B|^{2}/(2\\mu_0)| \\rangle_{vol}$, $\\phi \\cdot N_{FP}/2\\pi = 0.500$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <Axes: title={'center': '$|\\mathbf{J} \\times \\mathbf{B} - \\nabla p|$ / $\\langle |\\nabla |B|^{2}/(2\\mu_0)| \\rangle_{vol}$, $\\phi \\cdot N_{FP}/2\\pi = 0.667$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>,
#         <Axes: title={'center': '$|\\mathbf{J} \\times \\mathbf{B} - \\nabla p|$ / $\\langle |\\nabla |B|^{2}/(2\\mu_0)| \\rangle_{vol}$, $\\phi \\cdot N_{FP}/2\\pi = 0.833$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>],
#        dtype=object))
