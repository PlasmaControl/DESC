# %%
# Testing objective function output

import desc.io
from desc.objectives import (
    TrappedResonance
)
import numpy as np
eq_init = desc.io.load("desc_eq_new_QH_aScaling.h5")
obj = TrappedResonance(eq_init) # grid is set in init of TrappedResonance class
obj.build()
value = obj.compute(eq_init.params_dict)
# value = eq_init.compute('f_tr',grid=grid)

print(value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/integrals/_interp_utils.py:18
#      17 try:
# ---> 18     from jax_finufft import nufft2, options
#      19 except ImportError:
#
# ModuleNotFoundError: No module named 'jax_finufft'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Testing objective function output
#       3 import desc.io
# ----> 4 from desc.objectives import (
#       5     TrappedResonance
#       6 )
#       7 import numpy as np
#       8 eq_init = desc.io.load("desc_eq_new_QH_aScaling.h5")
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/objectives/__init__.py:3
#       1 """Classes defining objectives for equilibrium and optimization."""
# ----> 3 from ._bootstrap import BootstrapRedlConsistency
#       4 from ._coils import (
#       5     CoilArclengthVariance,
#       6     CoilCurrentLength,
#    (...)     19     ToroidalFlux,
#      20 )
#      21 from ._equilibrium import (
#      22     CurrentDensity,
#      23     Energy,
#    (...)     27     RadialForceBalance,
#      28 )
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/objectives/_bootstrap.py:6
#       3 import numpy as np
#       5 from desc.backend import jnp
# ----> 6 from desc.compute import get_profiles, get_transforms
#       7 from desc.compute.utils import _compute as compute_fun
#       8 from desc.grid import LinearGrid
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/compute/__init__.py:30
#      26 # just need to import all the submodules here to register everything in the
#      27 # data_index
#      29 from ..utils import rpz2xyz, rpz2xyz_vec, xyz2rpz, xyz2rpz_vec
# ---> 30 from . import (
#      31     _basis_vectors,
#      32     _bootstrap,
#      33     _core,
#      34     _curve,
#      35     _equil,
#      36     _fast_ion,
#      37     _field,
#      38     _geometry,
#      39     _metric,
#      40     _neoclassical,
#      41     _old,
#      42     _omnigenity,
#      43     _profiles,
#      44     _stability,
#      45     _surface,
#      46 )
#      47 from .data_index import all_kwargs, allowed_kwargs, data_index
#      48 from .utils import (
#      49     compute,
#      50     get_data_deps,
#    (...)     55     profile_names,
#      56 )
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/compute/_bootstrap.py:16
#      13 from scipy.special import roots_legendre
#      15 from ..backend import fori_loop, jnp
# ---> 16 from ..integrals.surface_integral import surface_averages_map
#      17 from ..profiles import PowerSeriesProfile
#      18 from .data_index import register_compute_fun
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/integrals/__init__.py:3
#       1 """Classes for function integration."""
# ----> 3 from ._bounce_utils import fast_chebyshev, fast_cubic_spline, fourier_chebyshev
#       4 from ._interp_utils import nufft1d2r, nufft2d2r
#       5 from .bounce_integral import Bounce1D, Bounce2D
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/integrals/_bounce_utils.py:8
#       5 from matplotlib import pyplot as plt
#       7 from desc.backend import dct, ifft, jnp
# ----> 8 from desc.integrals._interp_utils import (
#       9     cheb_from_dct,
#      10     cheb_pts,
#      11     idct_mmt,
#      12     ifft_mmt,
#      13     irfft_mmt,
#      14     nufft1d2r,
#      15     polyroot_vec,
#      16     polyval_vec,
#      17 )
#      18 from desc.integrals.basis import (
#      19     FourierChebyshevSeries,
#      20     PiecewiseChebyshevSeries,
#    (...)     23     _plot_intersect,
#      24 )
#      25 from desc.integrals.quad_utils import bijection_from_disc
#
# File ~/codes/DESC_fork_08282025/DESC_TrappedRes/desc/integrals/_interp_utils.py:21
#      18     from jax_finufft import nufft2, options
#      19 except ImportError:
#      20     warnings.warn(
# ---> 21         colored(
#      22             "\njax-finufft is not installed.\n"
#      23             "You must set the parameter nufft_eps to zero, e.g. ``nufft_eps=0``\n",
#      24             "when computing effective ripple, Gamma_c, and any other computations\n"
#      25             "that involve bounce integrals.\n"
#      26             "yellow",
#      27         )
#      28     )
#      30 from desc.backend import dct, jnp, rfft, rfft2, take
#      31 from desc.integrals.quad_utils import bijection_from_disc
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/DESC_fork_08282025/lib/python3.13/site-packages/termcolor/termcolor.py:169, in colored(text, color, on_color, attrs, no_color, force_color)
#     167 if color is not None:
#     168     if isinstance(color, str):
# --> 169         result = fmt_str % (COLORS[color], result)
#     170     elif isinstance(color, tuple):
#     171         result = rgb_fore_fmt_str % (color[0], color[1], color[2], result)
#
# KeyError: 'when computing effective ripple, Gamma_c, and any other computations\nthat involve bounce integrals.\nyellow'
